# %%
import pandas as pd

# %%
df = pd.read_csv("turkiye_kira_p1.csv")
len(df.columns)
# Out:
# 38

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3202 entries, 0 to 3201
# Data columns (total 38 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   İlan Numarası              3194 non-null   float64
#  1   İlan Oluşturma Tarihi      3194 non-null   object
#  2   İlan Güncelleme Tarihi     3194 non-null   object
#  3   Türü                       3194 non-null   object
#  4   Kategorisi                 3194 non-null   object
#  5   Tipi                       3194 non-null   object
#  6   Net Metrekare              3194 non-null   object
#  7   Brüt Metrekare             3194 non-null   object
#  8   Oda Sayısı                 3194 non-null   object
#  9   Binanın Yaşı               3194 non-null   object
#  10  Bulunduğu Kat              3194 non-null   object
#  11  Binanın Kat Sayısı         3194 non-null   float64
#  12  Isıtma Tipi                3194 non-null   object
# ...
