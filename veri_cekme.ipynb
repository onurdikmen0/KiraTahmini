# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
url = "https://www.emlakjet.com/kiralik-daire/duzce"
response = requests.get(url)
soup = BeautifulSoup(response.content, "html")

# %%
response
# Out:
# <Response [200]>

# %%
soup

# %%
st1 = soup.find("div", attrs= {"class : styles_wrapper__aHXTR"})
st2 = soup.find_all("div", attrs= {"styles_listingWrapper__I0H_l"})

# %%
def data_scraping(tag:str, attr:str ,attr_value:str) -> np.array:
    data_list = []
    if attr == "class_":
        data = soup.find_all(f"{tag}", class_ = f"{attr_value}")
    for i in data:
        data_list.append(i.get_text())

    return data_list

# %%
locations = data_scraping("span", "class_","styles_location__ieVpH")
explanations = data_scraping("h3", "class_","styles_title__CN_n3")
informations = data_scraping("div", "class_" ,"styles_quickinfoWrapper__F5BBD")
sales_prices = data_scraping("div", "class_", "styles_priceContent__TBOLV")

# %%
dataset = {"locations"    : locations,
#           "explanations" : explanations,
           "informations" : informations,
           "sales_price"  : sales_prices
           }
df = pd.DataFrame(dataset)
df
# Out:
#                                        locations  \
# 0             Düzce Merkez - Orhangazi Mahallesi
# 1               Düzce Merkez - Aziziye Mahallesi
# 2             Düzce Merkez - Orhangazi Mahallesi
# 3             Düzce Merkez - Orhangazi Mahallesi
# 4             Düzce Merkez - Orhangazi Mahallesi
# 5     Düzce Merkez - Şehit Murat Demir Mahallesi
# 6     Düzce Merkez - Şehit Murat Demir Mahallesi
# 7               Düzce Merkez - Aziziye Mahallesi
# 8     Düzce Merkez - Şehit Murat Demir Mahallesi
# 9                Düzce Merkez - Kültür Mahallesi
# 10    Düzce Merkez - Şehit Murat Demir Mahallesi
# 11            Düzce Merkez - Orhangazi Mahallesi
# 12               Düzce Merkez - Karaca Mahallesi
# 13            Düzce Merkez - Orhangazi Mahallesi
# 14            Düzce Merkez - Orhangazi Mahallesi
# 15    Düzce Merkez - Şehit Murat Demir Mahallesi
# 16    Düzce Merkez - Şehit Murat Demir Mahallesi
# 17    Düzce Merkez - Şehit Murat Demir Mahallesi
# 18            Düzce Merkez - Körpeşler Mahallesi
# 19  Düzce Merkez - Şehit Bayram Gökmen Mahallesi
# 20             Düzce Merkez - Hamidiye Mahallesi
# 21            Düzce Merkez - Orhangazi Mahallesi
# 22            Düzce Merkez - Orhangazi Mahallesi
# 23            Düzce Merkez - Orhangazi Mahallesi
# 24            Düzce Merkez - Orhangazi Mahallesi
# 25          Düzce Merkez - Fevziçakmak Mahallesi
# 26            Düzce Merkez - Camikebir Mahallesi
# 27              Düzce Merkez - Aziziye Mahallesi
# 28                  Düzce Merkez - Çay Mahallesi
# 29              Düzce Merkez - Aziziye Mahallesi
#
#                                informations sales_price
# 0        Daire | 1+1 | Yüksek giriş | 50 m²   11.000 TL
# 1             Daire | 2+1 | 1. Kat | 170 m²   12.500 TL
# 2              Daire | 1+1 | 1. Kat | 60 m²   10.500 TL
# 3              Daire | 2+1 | 3. Kat | 70 m²   17.000 TL
# 4              Daire | 1+1 | 7. Kat | 45 m²   10.000 TL
# 5              Daire | 1+1 | 3. Kat | 55 m²   10.000 TL
# 6              Daire | 2+1 | 1. Kat | 90 m²   15.000 TL
# 7   Daire | 1+1 | Düz Giriş (Zemin) | 50 m²   10.000 TL
# 8              Daire | 2+1 | 4. Kat | 65 m²   15.000 TL
# 9              Daire | 1+1 | 4. Kat | 55 m²   21.000 TL
# 10             Daire | 1+1 | 2. Kat | 72 m²   11.000 TL
# 11            Daire | 1+1 | 10. Kat | 61 m²   10.000 TL
# 12            Daire | 2+1 | 2. Kat | 100 m²   14.000 TL
# 13             Daire | 1+1 | 7. Kat | 45 m²   10.000 TL
# 14             Daire | 1+1 | 7. Kat | 55 m²   10.000 TL
# 15             Daire | 2+1 | 2. Kat | 90 m²   15.500 TL
# 16             Daire | 1+1 | 3. Kat | 60 m²   13.000 TL
# 17       Daire | 1+1 | Yüksek giriş | 55 m²   10.000 TL
# 18            Daire | 3+1 | 2. Kat | 120 m²   20.000 TL
# 19             Daire | 1+1 | 2. Kat | 60 m²   14.000 TL
# 20            Daire | 3+1 | 3. Kat | 150 m²   11.000 TL
# 21             Daire | 1+1 | 3. Kat | 60 m²   13.500 TL
# 22             Daire | 2+0 | 4. Kat | 70 m²    8.250 TL
# 23             Daire | 1+1 | 5. Kat | 55 m²   12.500 TL
# 24             Daire | 1+1 | 1. Kat | 62 m²   12.000 TL
# 25            Daire | 3+1 | 2. Kat | 130 m²   19.000 TL
# 26             Daire | 2+1 | 3. Kat | 95 m²   15.000 TL
# 27            Daire | 2+1 | 3. Kat | 100 m²   18.000 TL
# 28      Daire | 3+1 | Yüksek giriş | 130 m²   17.500 TL
# 29            Daire | 3+1 | 3. Kat | 135 m²   20.500 TL
