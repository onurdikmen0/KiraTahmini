# %% [markdown]
# https://www.e-icisleri.gov.tr/Anasayfa/MulkiIdariBolumleri.aspx? adresinden Türkiyedeki il, ilçe ve mahalle bilgilerini içerine 3 tane dosya indirdim.

# %%
import pandas as pd

# Excel dosyasını oku
excel_dosyasi = "excel\\Il_Listesi.xls"
df = pd.read_excel(excel_dosyasi)

# İlk 5 satırı göster
print(df.head())

# Belirli bir sütunu seç
print(df['İl_Adı'])  # Eğer sütun adı "İl_Adı" ise

# Koşula göre veri filtreleme
istanbul_veri = df[df['İl_Adı'] == 'İstanbul']
print(istanbul_veri)
